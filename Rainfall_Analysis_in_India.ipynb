# %% [markdown]
# **RAINFALL ANALYSIS IN INDIA**

# %% [markdown]
# My analysis is based on Rainfall occured in India from year 1901-2015. I made statistical analysis and visualised the data to draw the valuable insights for our country India. I had analysed different months, seasons, annual rainfall data for different states, over wide range of years to explore data and make necessary inferences. I had used visualisation tools like Seaborn, Matplotlib, Folium. I used flask web framework for web frontend.
# Below are my statistical plots with analysis!!!

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as py
import plotly.offline
# %matplotlib inline

# %%
df = pd.read_csv("/content/sample_data/rainfall in india 1901-2015.csv")
df.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
df = df.rename(columns = {'SUBDIVISION':'STATE'})

# %% [markdown]
# ### **Annual Rainfall received by each State over years**

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = 'YEAR', y= 'ANNUAL', hue = 'STATE', data = df)
plt.title('Annual Rainfall received',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Annual Rainfall received')

# %% [markdown]
# Here, I plotted a graph to depict the annual rainfall received by each state over a span of years from 1901 - 2015. From this graph, we can have a general outlook about the states receiving huge amount of rainfall and those with minimal rainfall.

# %% [markdown]
# ### **Highest Rainfall ever received in a year in States**

# %%
plt.figure(figsize=(15,8))
df.groupby(['STATE','YEAR'])['ANNUAL'].sum().sort_values(ascending=False).plot()

plt.grid()
plt.xlabel("State,Year",fontsize=15)
plt.ylabel("Annual Rainfall received",fontsize=15)
plt.title('Highest Rainfall year Data of States',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Highest Rainfall year Data of States')

# %% [markdown]
# Here, the plot represents the analysis of the highest amount of annual rainfall recieved in the states , over the span of years from 1901-2015.
# From here, we can infer that the highest amount of rainfall ever received in span of given data is in year 1948, in the state Arunachal Pradesh.

# %% [markdown]
# ### **Total amount of rainfall recieved overall by each state**

# %%
plt.figure(figsize=(15,10))
df.groupby(['STATE'])['ANNUAL'].sum().sort_values(ascending=False).head(15).plot(kind='bar', color = 'black')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall Data',fontsize=20)
plt.grid()

# %% [markdown]
# Here, the plot represents the analysis of the total amount of annual rainfall recieved in the states , over the total span of years from 1901-2015. From here, we can infer that the highest amount of rainfall receiving state overall is Coastal Karnataka.

# %% [markdown]
# ### **The month with the hightest rainfall**

# %%
plt.figure(figsize=(10,7))
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG',
       'SEP', 'OCT', 'NOV', 'DEC']].mean().plot(kind= 'bar', color='red')
plt.xlabel('Months',fontsize=15)
plt.ylabel('Avg. Rainfall',fontsize=15)
plt.title('Avg. Monthly Rainfall Data',fontsize=25)
plt.grid()
plt.show()

# %% [markdown]
# From graph, we analysed July has the most rainfall on average. By contrast, December has the least rainfall. Moreover, there are many differences in rainfall amount among months.

# %% [markdown]
# ### **Season wise rainfall in India**

# %%
plt.figure(figsize=(10,2))
df[['STATE', 'Jan-Feb', 'Mar-May',
       'Jun-Sep', 'Oct-Dec']].groupby("STATE").mean().sort_values('Jun-Sep').plot.bar(width=0.5,edgecolor='k',align='center',stacked=True,figsize=(16,8))
plt.xlabel('STATE',fontsize=15)
plt.ylabel('Rainfall (in mm)',fontsize=15)
plt.title('Rainfall in States of India',fontsize=25)
plt.grid()

# %% [markdown]
# The above graph depicts the average rainfall received in each season in varous states of India.
# From here, we can conclude about the highest rainfall receiving state of India and can see that in which season our country receives the highest rainfall, which results to be Jun-Sept and thus we sorted the graph according to average amount lof rainfall in this season.

# %% [markdown]
# ### **Heat Map of Rainfall**

# %%
fig=plt.gcf()
fig.set_size_inches(15,15)
fig=sns.heatmap(df.corr(),annot=True,linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %% [markdown]
# From here, we can see that Annual rainfall has very high correlation to the rainfall received in the months of Jun-Sep

# %% [markdown]
# ### **Annual Rainfall from Year 1901 to 2015 in India**

# %%
# Visualizing annual rainfall over the years(1901-2015) in India
df.groupby("YEAR").mean()['ANNUAL'].plot(ylim=(1000,2000),color='k',marker='o',markerfacecolor='red',linestyle='-',linewidth=2,figsize=(12,10))
plt.xlabel('Year',fontsize=20)
plt.ylabel('Annual Rainfall (in mm)',fontsize=20)
plt.title('Annual Rainfall from Year 1901 to 2015 in India',fontsize=25)

plt.grid()

# %% [markdown]
# The graph above depicts the average rainfall received each year in India over the years from 1901- 2015. Hence, we can summarise about the years when there was very less rainfall in India, and when the rainfall was more.

# %% [markdown]
# ### **Box Plot of Annual Rainfall in States of India**

# %%
plt.rcParams['figure.figsize']=(18,8)
ax = sns.boxplot(x="STATE", y="ANNUAL", data=df, width=0.8,linewidth=3)
ax.set_xlabel('State',fontsize=20)
ax.set_ylabel('Annual Rainfall (in mm)',fontsize=20)
plt.title('Annual Rainfall in States of India',fontsize=30)
ax.tick_params(axis='x',labelsize=10,rotation=90)
ax.tick_params(axis='y',labelsize=10,rotation=0)
plt.grid()

# %% [markdown]
# From here, we can see that Arunachal Pradesh has recorded maximum rainfall annually but its median is similar to Coastal Karnataka, which means their average of total annual rainfall over years is approximately same, but the highest ever rainfall in a year is received by Arunachal Pradesh.
